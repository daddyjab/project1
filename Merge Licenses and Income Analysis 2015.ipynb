# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_licenses = pd.read_csv("Licenses_2015_Chicago.csv")
df_income = pd.read_csv("Income_2015_Chicago.csv")

# %%
df_licenses.head()
# Out:
#    Unnamed: 0  LICENSE NUMBER             LEGAL NAME   DOING BUSINESS AS NAME  \
# 0           0         23031.0  STARBUCKS CORPORATION    STARBUCKS COFFEE #216
# 1           1       1573094.0  STARBUCKS CORPORATION   STARBUCKS COFFEE #9426
# 2           2       1124102.0  STARBUCKS CORPORATION   STARBUCKS COFFEE #2510
# 3           3       2253113.0  STARBUCKS CORPORATION         STARBUCKS #17743
# 4           5       2089469.0  STARBUCKS CORPORATION  STARBUCKS COFFEE #15683
#
#    LICENSE CODE APPLICATION TYPE     CITY  WARD  ZIP CODE DATE ISSUED  \
# 0          1006            RENEW  CHICAGO  42.0   60611.0  03/18/2015
# 1          1006            RENEW  CHICAGO   1.0   60642.0  03/18/2015
# 2          1006            RENEW  CHICAGO  42.0   60610.0  03/18/2015
# 3          1006            RENEW  CHICAGO  40.0   60659.0  03/18/2015
# 4          1006            RENEW  CHICAGO  42.0   60602.0  03/18/2015
#
#     LATITUDE  LONGITUDE  YEAR
# 0  41.893341 -87.617589  2015
# ...

# %%
df_income.head()
# Out:
#    Unnamed: 0  COMMUNITY AREA COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0           7               8     Near North Side                         1.9
# 1           6               7        Lincoln Park                         0.8
# 2          31              32                Loop                         1.5
# 3           5               6           Lake View                         1.1
# 4          32              33     Near South Side                         1.3
#
#    PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                              12.9                          7.0
# 1                              12.3                          5.1
# 2                              14.7                          5.7
# 3                              11.4                          4.7
# 4                              13.8                          4.9
#
#    PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                           2.5
# ...

# %%
df_zip = df_licenses.groupby(['ZIP CODE']).count()

# %%
df_zip
# Out:
#           Unnamed: 0  LICENSE NUMBER  LEGAL NAME  DOING BUSINESS AS NAME  \
# ZIP CODE
# 60601.0           65              65          65                      65
# 60602.0           31              31          31                      31
# 60603.0           44              44          44                      44
# 60604.0           26              26          26                      26
# 60605.0           57              57          57                      57
# 60606.0           87              87          87                      87
# 60607.0           98              98          98                      98
# 60608.0          232             232         232                     232
# 60609.0          118             118         118                     118
# 60610.0          103             103         103                     103
# 60611.0          329             329         329                     329
# 60612.0           59              59          59                      59
# ...

# %%
df_zip1 = df_zip['LICENSE NUMBER']

# %%
df_zip1.head
# Out:
# <bound method NDFrame.head of ZIP CODE
# 60601.0     65
# 60602.0     31
# 60603.0     44
# 60604.0     26
# 60605.0     57
# 60606.0     87
# 60607.0     98
# 60608.0    232
# 60609.0    118
# 60610.0    103
# 60611.0    329
# 60612.0     59
# 60613.0     71
# 60614.0    392
# 60615.0     35
# 60616.0     79
# 60617.0     66
# 60618.0    154
# 60619.0     67
# 60620.0     59
# 60621.0     38
# 60622.0    131
# 60623.0     85
# 60624.0     35
# 60625.0    273
# 60626.0     61
# 60628.0    134
# 60629.0    182
# 60630.0    119
# 60631.0     23
# 60632.0    268
# 60633.0     19
# 60634.0    179
# 60636.0     92
# 60637.0    107
# 60638.0     73
# 60639.0    202
# 60640.0    229
# 60641.0    153
# 60642.0     69
# 60643.0    101
# 60644.0    103
# 60645.0     62
# 60646.0     18
# 60647.0    335
# 60649.0     47
# 60651.0    124
# 60652.0     71
# 60653.0     37
# 60654.0     87
# 60655.0     24
# 60656.0     29
# 60657.0    300
# 60659.0    176
# 60660.0    119
# 60661.0    119
# ...

# %%
df_complete = pd.read_csv("Chicago_Licenses.csv")
df_complete.head()
# Out:
#                  ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 0    22308-20060816     1723393           29481            1
# 1  1620668-20160516     2455262          295026            1
# 2  2368602-20160616     2460909          291461            3
# 3  2060891-20141016     2353257          357247            1
# 4  1144216-20070516     1804790             147           63
#
#                           LEGAL NAME             DOING BUSINESS AS NAME  \
# 0              BELL OIL TERMINAL INC              Bell Oil Terminal LLC
# 1              BUCCI BIG & TALL INC.              BUCCI BIG & TALL INC.
# 2             PROJECT: VISION , INC.             PROJECT : VISION , INC
# 3  FOLASHADE'S CLEANING SERVICE INC.  FOLASHADE'S CLEANING SERVICE INC.
# 4                       WALGREEN CO.                  Walgreens # 05192
#
#                      ADDRESS     CITY STATE ZIP CODE  \
# 0       3741 S PULASKI RD  1  CHICAGO    IL    60623
# 1         558 W ROOSEVELT RD  CHICAGO    IL    60607
# ...

# %%
df_chicago = df_complete.query('CITY == "CHICAGO"')

# %%
df_1006 = df_chicago[df_chicago['LICENSE CODE'] == 1006]

# %%
df_1006.dropna()
# Out:
#                       ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 18963   2334308-20141017     2334308          390916            1
# 23907   2451833-20160325     2451833          404369            1
# 23982   2423202-20150831     2423202          400840            1
# 28921   2369176-20141226     2369176          395228            1
# 29031   2368177-20141201     2368177          393442            2
# 37303   2327214-20140521     2327214          389959            1
# 39304   2373480-20150120     2373480          395282            1
# 40274   2457892-20160407     2457892          404954            1
# 44692   2385837-20150318     2385837          358003            2
# 48076   2386006-20160324     2386006          396847            1
# 50186   2446341-20160331     2446341          403702            1
# 54075   2446798-20160405     2446798          403915            1
# 55293   2398096-20150701     2398096          398126            1
# ...

# %%
df_zip_total = df_1006.groupby(['ZIP CODE']).count()

# %%
df_zip_ok = df_zip_total['LICENSE NUMBER']

# %%
zip_income = pd.read_csv('chicago_zip_income_1.csv')

# %%
zip_income.dropna()
# Out:
#     ZIP CODE  LICENSES 2015  LICENSES 2002-18  HOUSEHOLD INCOME
# 0    60601.0           65.0            1309.0          156723.0
# 1    60602.0           31.0             534.0          172492.0
# 2    60603.0           44.0             720.0          121184.0
# 3    60604.0           26.0             552.0          114724.0
# 4    60605.0           57.0             877.0          157763.0
# 5    60606.0           87.0            1322.0          134625.0
# 6    60607.0           98.0            1310.0          120419.0
# 7    60608.0          232.0            2060.0           57770.0
# 8    60609.0          118.0            1500.0           47139.0
# 9    60610.0          103.0            1951.0          132877.0
# 10   60611.0          329.0            2381.0          159285.0
# 11   60612.0           59.0             866.0           60654.0
# 12   60613.0           71.0            1407.0          113058.0
# 13   60614.0          392.0            2567.0          149897.0
# ...

# %%
x = zip_income['LICENSES 2002-18']

# %%
Y = zip_income['HOUSEHOLD INCOME']

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 15,7.5
plt.scatter(x, Y)
plt.xlabel('Number of Restaurant Liceneses')
plt.ylabel('Average Household Income by Zip Code ($)')
plt.title('Correlation between Household Income and Issued Licenses by Zip Code')
plt.savefig('correlation_income_licenses.png')

# %%
zip_income['HOUSEHOLD INCOME'].corr(zip_income['LICENSES 2002-18'])
# Out:
# 0.14850736258242161
