# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
#import time

import random as random
import gmaps
from pprint import pprint
#import pycountry
#from IPython.display import (Image, HTML)
#import logging
#import math
#from scipy import stats

# Keys
from api_config import (key_openweathermap, key_gmaps)

# Incorporated citipy to determine city based on latitude and longitude
#from citipy import citipy

# %% [markdown]
# # Data sources to explore (so far)
# * Chicago:
#     * Chicago Transit Authority: https://www.transitchicago.com/developers/
#         * CTA Transit Stops - General Transit Feed Specification (GTFS): "Data/access-Chicago-CTA-stops.txt"
#
#     * Chicago Taxi Trips: https://www.kaggle.com/chicago/chicago-taxi-trips-bq/home
#     * Chicago Taxi Rides 2016: https://www.kaggle.com/chicago/chicago-taxi-rides-2016
# * Los Angeles
# * New York:
# * San Francisco
# * Washington, D.C.

# %%
# Read in the Chicago CTA General Transit Feed Specification (GTFS) stops.txt file
i_file = "./access-Chicago-CTA-stops.txt"

# Data Cleaning: Force 2 columns stop_code and parent_station to be "object" (vs. 'int64')
#  since some inputs values are empty, which for some reason returns an error if these are 'int64'
i_dtypes = {'stop_id':'int64', 'stop_code':'object',
            'stop_name':'object', 'stop_desc':'object',
            'stop_lat':'float64', 'stop_lon':'float64',
            'location_type':'int64', 'parent_station':'object', 'wheelchair_boarding':'int64'
            }
c_cta_stops_df = pd.read_csv(i_file, dtype = i_dtypes)

# %%
c_cta_stops_df.head()
# Out:
#    stop_id stop_code                  stop_name  \
# 0        1         1  Jackson & Austin Terminal
# 1        2         2             5900 W Jackson
# 2        3         3           Jackson & Menard
# 3        4         4             5700 W Jackson
# 4        6         6            Jackson & Lotus
#
#                                            stop_desc   stop_lat   stop_lon  \
# 0  Jackson & Austin Terminal, Northeastbound, Bus...  41.876322 -87.774105
# 1  5900 W Jackson, Eastbound, Southside of the St...  41.877067 -87.771318
# 2  Jackson & Menard, Eastbound, Southside of the ...  41.876957 -87.769750
# 3  5700 W Jackson, Eastbound, Southside of the St...  41.877024 -87.767451
# 4       Jackson & Lotus, Eastbound, Southeast Corner  41.876513 -87.761446
#
#    location_type parent_station  wheelchair_boarding
# 0              0            NaN                    1
# 1              0            NaN                    1
# 2              0            NaN                    1
# 3              0            NaN                    1
# 4              0            NaN                    1

# %%
# Keep keep only the rows where parent_station is NaN.
# (some rows are direction-specific 'stop_id',
#  with each 'parent_station' allowed one or more directly-specific 'stop_id' entries.
#  but for this analysis we only need to know the parent_station information
c_cta_stops_df = c_cta_stops_df.loc[ c_cta_stops_df[ 'parent_station'].isnull() ]
c_cta_stops_df.head()
# Out:
#    stop_id stop_code                  stop_name  \
# 0        1         1  Jackson & Austin Terminal
# 1        2         2             5900 W Jackson
# 2        3         3           Jackson & Menard
# 3        4         4             5700 W Jackson
# 4        6         6            Jackson & Lotus
#
#                                            stop_desc   stop_lat   stop_lon  \
# 0  Jackson & Austin Terminal, Northeastbound, Bus...  41.876322 -87.774105
# 1  5900 W Jackson, Eastbound, Southside of the St...  41.877067 -87.771318
# 2  Jackson & Menard, Eastbound, Southside of the ...  41.876957 -87.769750
# 3  5700 W Jackson, Eastbound, Southside of the St...  41.877024 -87.767451
# 4       Jackson & Lotus, Eastbound, Southeast Corner  41.876513 -87.761446
#
#    location_type parent_station  wheelchair_boarding
# 0              0            NaN                    1
# 1              0            NaN                    1
# 2              0            NaN                    1
# 3              0            NaN                    1
# 4              0            NaN                    1

# %%
# Use reverse geocode lookup to find a
#  postal_code (zipcode) associated with a lat/long coor
def zipcode_from_latlong( a_lat, a_long ):
    baseurl = "https://maps.googleapis.com/maps/api/geocode/json?"
    latlong = f"latlng={a_lat},{a_long}"
    api_key = f"&key={key_gmaps}"
    
    full_url = baseurl + latlong + api_key

    # Perform a reverse geocode loopup to find the zipcode associated with this lat/long coord
    g_response = requests.get(full_url)
    g_json = g_response.json()
    
    # Traverse the results to find a zipcode for this address
    zipcode = None
    for a in r_json['results'][0]['address_components']:
        if 'postal_code' in a['types']:
            zipcode = a['long_name']
            
    # Return the zipcode that was found
    return zipcode

# %%
# Now, populate postal_code(zipcode) for all of the CTA stops
for si in c_cta_stops_df.index:
    c_cta_stops_df['postal_code'] = zipcode_from_latlong(
                                    c_cta_stops_df['stop_lat'][si],
                                    c_cta_stops_df['stop_lon'][si])

# %%
c_cta_stops_df.head(20)
# Out:
#     stop_id stop_code                  stop_name  \
# 0         1         1  Jackson & Austin Terminal
# 1         2         2             5900 W Jackson
# 2         3         3           Jackson & Menard
# 3         4         4             5700 W Jackson
# 4         6         6            Jackson & Lotus
# 5         7         7             5351 W Jackson
# 6         8         8         Jackson & Lockwood
# 7         9         9          Jackson & Laramie
# 8        10        10       Jackson & Leamington
# 9        11        11             5047 W Jackson
# 10       12        12         Jackson & Lavergne
# 11       13        13             4849 W Jackson
# 12       14        14           Jackson & Cicero
# 13       15        15       Jackson & Kilpatrick
# 14       16        16           Jackson & Kenton
# 15       17        17           Jackson & Kolmar
# 16       18        18         Jackson & Kilbourn
# 17       19        19          Jackson & Kostner
# 18       20        20          Jackson & Kildare
# 19       21        21           Jackson & Keeler
#
#                                             stop_desc   stop_lat   stop_lon  \
# 0   Jackson & Austin Terminal, Northeastbound, Bus...  41.876322 -87.774105
# 1   5900 W Jackson, Eastbound, Southside of the St...  41.877067 -87.771318
# 2   Jackson & Menard, Eastbound, Southside of the ...  41.876957 -87.769750
# 3   5700 W Jackson, Eastbound, Southside of the St...  41.877024 -87.767451
# 4        Jackson & Lotus, Eastbound, Southeast Corner  41.876513 -87.761446
# 5   5351 W Jackson, Eastbound, Southside of the St...  41.876552 -87.758925
# 6     Jackson & Lockwood, Eastbound, Southeast Corner  41.876564 -87.757313
# 7      Jackson & Laramie, Eastbound, Southeast Corner  41.876595 -87.754615
# 8   Jackson & Leamington, Eastbound, Southeast Corner  41.876626 -87.753168
# 9   5047 W Jackson, Eastbound, Southside of the St...  41.876651 -87.751283
# 10    Jackson & Lavergne, Eastbound, Southeast Corner  41.876621 -87.749124
# 11  4849 W Jackson, Eastbound, Southside of the St...  41.876689 -87.747017
# 12      Jackson & Cicero, Eastbound, Southeast Corner  41.876763 -87.744831
# 13  Jackson & Kilpatrick, Eastbound, Southeast Corner  41.876830 -87.742549
# 14  Jackson & Kenton, Eastbound, Southside of the ...  41.876834 -87.740585
# 15      Jackson & Kolmar, Eastbound, Southeast Corner  41.876857 -87.739347
# 16    Jackson & Kilbourn, Eastbound, Southeast Corner  41.876886 -87.737614
# 17     Jackson & Kostner, Eastbound, Southeast Corner  41.876915 -87.735159
# 18     Jackson & Kildare, Eastbound, Southeast Corner  41.876933 -87.732650
# 19      Jackson & Keeler, Eastbound, Southeast Corner  41.876963 -87.730200
#
#     location_type parent_station  wheelchair_boarding postal_code
# 0               0            NaN                    1       60644
# 1               0            NaN                    1       60644
# 2               0            NaN                    1       60644
# 3               0            NaN                    1       60644
# 4               0            NaN                    1       60644
# 5               0            NaN                    1       60644
# 6               0            NaN                    1       60644
# 7               0            NaN                    1       60644
# 8               0            NaN                    1       60644
# 9               0            NaN                    1       60644
# 10              0            NaN                    1       60644
# 11              0            NaN                    1       60644
# 12              0            NaN                    1       60644
# 13              0            NaN                    1       60644
# 14              0            NaN                    1       60644
# 15              0            NaN                    1       60644
# 16              0            NaN                    1       60644
# 17              0            NaN                    1       60644
# 18              0            NaN                    1       60644
# 19              0            NaN                    1       60644

# %%
# Save the dataframe to a csv file for later use
o_file = "./chicago_cta_stops.csv"
c_cta_stops_df.to_csv(o_file, index=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b39c9fd4e1c0> in <module>()
# ----> 1 c_cta_stops_df.head()
#
# NameError: name 'c_cta_stops_df' is not defined
