# %%
#Import Pandas and read csv file
import pandas
df = pandas.read_csv("Business_Licenses.csv")
df.head()
# Out:
# /Users/gallasteguicrino/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (9,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                  ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 0    22308-20060816     1723393           29481            1
# 1  1620668-20160516     2455262          295026            1
# 2  2368602-20160616     2460909          291461            3
# 3  2060891-20141016     2353257          357247            1
# 4  1144216-20070516     1804790             147           63
#
#                           LEGAL NAME             DOING BUSINESS AS NAME  \
# 0              BELL OIL TERMINAL INC              Bell Oil Terminal LLC
# 1              BUCCI BIG & TALL INC.              BUCCI BIG & TALL INC.
# 2             PROJECT: VISION , INC.             PROJECT : VISION , INC
# ...

# %%
df.shape
# Out:
# (957634, 34)

# %%
# List all variables as some were omited above. 
list(df)
# Out:
# ['ID',
#  'LICENSE ID',
#  'ACCOUNT NUMBER',
#  'SITE NUMBER',
#  'LEGAL NAME',
#  'DOING BUSINESS AS NAME',
#  'ADDRESS',
#  'CITY',
#  'STATE',
#  'ZIP CODE',
#  'WARD',
#  'PRECINCT',
#  'WARD PRECINCT',
#  'POLICE DISTRICT',
#  'LICENSE CODE',
#  'LICENSE DESCRIPTION',
#  'BUSINESS ACTIVITY ID',
#  'BUSINESS ACTIVITY',
#  'LICENSE NUMBER',
#  'APPLICATION TYPE',
#  'APPLICATION CREATED DATE',
#  'APPLICATION REQUIREMENTS COMPLETE',
#  'PAYMENT DATE',
#  'CONDITIONAL APPROVAL',
#  'LICENSE TERM START DATE',
#  'LICENSE TERM EXPIRATION DATE',
#  'LICENSE APPROVED FOR ISSUANCE',
#  'DATE ISSUED',
#  'LICENSE STATUS',
#  'LICENSE STATUS CHANGE DATE',
#  'SSA',
#  'LATITUDE',
#  'LONGITUDE',
#  'LOCATION']

# %%
# Create new dataframe with the variables we'll use. 
df_1 = df[["LEGAL NAME", 'DOING BUSINESS AS NAME', "LICENSE CODE", "CITY", "WARD", "ZIP CODE", "DATE ISSUED", "LATITUDE", "LONGITUDE", "LOCATION"]]
df_1.head()
# Out:
#                           LEGAL NAME             DOING BUSINESS AS NAME  \
# 0              BELL OIL TERMINAL INC              Bell Oil Terminal LLC
# 1              BUCCI BIG & TALL INC.              BUCCI BIG & TALL INC.
# 2             PROJECT: VISION , INC.             PROJECT : VISION , INC
# 3  FOLASHADE'S CLEANING SERVICE INC.  FOLASHADE'S CLEANING SERVICE INC.
# 4                       WALGREEN CO.                  Walgreens # 05192
#
#    LICENSE CODE     CITY  WARD ZIP CODE DATE ISSUED   LATITUDE  LONGITUDE  \
# 0          1010  CHICAGO  14.0    60623  08/11/2006  41.825320 -87.723960
# 1          1010  CHICAGO  25.0    60607  08/30/2016  41.867339 -87.641590
# 2          1625  CHICAGO  25.0    60616  06/22/2016  41.850843 -87.638734
# 3          1010  LANSING   NaN    60438  04/01/2016  41.951316 -87.678586
# 4          1010  CHICAGO  10.0    60617  05/11/2007  41.728622 -87.551366
#
#                                   LOCATION
# 0  (41.82531992987547, -87.72395999659746)
# ...

# %%
# Flter by city (Chicago) 
df_2 = df_1.query('CITY == "CHICAGO"')
df_2.head()
# Out:
#                                  LEGAL NAME  \
# 0                     BELL OIL TERMINAL INC
# 1                     BUCCI BIG & TALL INC.
# 2                    PROJECT: VISION , INC.
# 4                              WALGREEN CO.
# 5  BURKS HEATING AND COOLING SOLUTIONS, LLC
#
#                      DOING BUSINESS AS NAME  LICENSE CODE     CITY  WARD  \
# 0                     Bell Oil Terminal LLC          1010  CHICAGO  14.0
# 1                     BUCCI BIG & TALL INC.          1010  CHICAGO  25.0
# 2                    PROJECT : VISION , INC          1625  CHICAGO  25.0
# 4                         Walgreens # 05192          1010  CHICAGO  10.0
# 5  BURKS HEATING AND COOLING SOLUTIONS, LLC          4404  CHICAGO  15.0
#
#   ZIP CODE DATE ISSUED   LATITUDE  LONGITUDE  \
# 0    60623  08/11/2006  41.825320 -87.723960
# 1    60607  08/30/2016  41.867339 -87.641590
# 2    60616  06/22/2016  41.850843 -87.638734
# 4    60617  05/11/2007  41.728622 -87.551366
# ...

# %%
df_2.shape
# Out:
# (887891, 10)

# %%
# FIlter by license code
df_3 = df_2[df_2['LICENSE CODE'] == 1006]
df_3.shape
# Out:
# (141713, 10)

# %%
df_3
# Out:
#                                              LEGAL NAME  \
# 11                                    OLD TOWN OIL, LLC
# 35                                    MO MO HOUSE CORP.
# 44                             THIRD DEGREE CHICAGO LLC
# 47                                VIENNA SERVICES, INC.
# 63                                STARBUCKS CORPORATION
# 92                       GENERAL GROWTH MANAGEMENT INC.
# 107                               STARBUCKS CORPORATION
# 108                               STARBUCKS CORPORATION
# 111                                   KURIAN FOODS INC.
# 131                               STARBUCKS CORPORATION
# 141                                     FG TRADING INC.
# 218                               SRJ ENTERPRISES, INC.
# 224                             ROXANNE FOOD MART, INC.
# 227                                        THOMAS I. YI
# 237                                          LUFRAN INC
# 244                               STARBUCKS CORPORATION
# ...
